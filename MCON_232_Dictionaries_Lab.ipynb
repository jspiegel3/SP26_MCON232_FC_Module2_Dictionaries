# %% [markdown]
# <a href="https://colab.research.google.com/github/jspiegel3/SP26_MCON232_FC_Module2_Dictionaries/blob/main/MCON_232_Dictionaries_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Your Name
# ## Topic : Dictionaries Lab
